# %% [markdown]
# # ALS Project
#
# ### Vital Signs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## functions

# %% [markdown]
# ## Vitals

# %%
vital = pd.read_csv("data/VitalSigns.csv")

# %%
print(vital.shape)
vital.head()
# Out:
# (72422, 36)
#    subject_id  Blood_Pressure_Diastolic Blood_Pressure_Diastolic_Units  \
# 0         329                       NaN                            NaN
# 1         329                       NaN                            NaN
# 2         329                       NaN                            NaN
# 3         329                       NaN                            NaN
# 4         329                       NaN                            NaN
#
#    Blood_Pressure_Systolic Blood_Pressure_Systolic_Units  Height Height_Units  \
# 0                      NaN                           NaN   157.5          NaN
# 1                      NaN                           NaN     NaN          NaN
# 2                      NaN                           NaN     NaN          NaN
# 3                      NaN                           NaN     NaN          NaN
# 4                      NaN                           NaN     NaN          NaN
#
#    Pulse Pulse_Units  Respiratory_Rate  ... Baseline_Standing_Pulse  \
# 0    NaN         NaN               NaN  ...                     NaN
# 1    NaN         NaN              32.0  ...                     NaN
# 2    NaN         NaN              29.0  ...                     NaN
# 3    NaN         NaN              26.0  ...                     NaN
# 4    NaN         NaN              26.0  ...                     NaN
#
#    Endpoint_Weight Endpoint_Standing_BP_Diastolic  \
# 0              NaN                            NaN
# 1              NaN                            NaN
# 2              NaN                            NaN
# 3              NaN                            NaN
# 4              NaN                            NaN
#
#    Endpoint_Standing_BP_Systolic Endpoint_Supine_BP_Diastolic  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#    Endpoint_Supine_BP_Systolic  Supine_BP_Diastolic  Supine_BP_Systolic  \
# 0                          NaN                  NaN                 NaN
# 1                          NaN                 70.0               110.0
# 2                          NaN                 65.0               107.0
# 3                          NaN                 60.0               104.0
# 4                          NaN                 70.0               120.0
#
#    Standing_BP_Diastolic  Standing_BP_Systolic
# 0                    NaN                   NaN
# 1                   60.0                 106.0
# 2                   65.0                 107.0
# 3                   70.0                 108.0
# 4                   64.0                 112.0
#
# [5 rows x 36 columns]

# %%
# add days since disease onset
onset=pd.read_csv("clean_data/onset_date.csv")
onset=onset[['subject_id', 'Onset_Delta']].copy()
onset.head()
# Out:
#    subject_id  Onset_Delta
# 0         329      -1706.0
# 1         348       -501.0
# 2         533      -1023.0
# 3         586       -715.0
# 4         649       -341.0

# %%
vital = vital.merge(onset, how='outer', on='subject_id')

# %%
vital.columns
# Out:
# Index(['subject_id', 'Blood_Pressure_Diastolic',
#        'Blood_Pressure_Diastolic_Units', 'Blood_Pressure_Systolic',
#        'Blood_Pressure_Systolic_Units', 'Height', 'Height_Units', 'Pulse',
#        'Pulse_Units', 'Respiratory_Rate', 'Respiratory_Rate_Units',
#        'Temperature', 'Temperature_Units', 'Weight', 'Weight_Units',
#        'Vital_Signs_Delta', 'Baseline_Standing_BP_Diastolic',
#        'Baseline_Standing_BP_Systolic', 'Baseline_Supine_BP_Diastolic',
#        'Baseline_Supine_BP_Systolic', 'Baseline_Weight', 'Supine_Pulse',
#        'Standing_Pulse', 'Endpoint_Supine_Pulse', 'Endpoint_Standing_Pulse',
#        'Baseline_Supine_Pulse', 'Baseline_Standing_Pulse', 'Endpoint_Weight',
#        'Endpoint_Standing_BP_Diastolic', 'Endpoint_Standing_BP_Systolic',
#        'Endpoint_Supine_BP_Diastolic', 'Endpoint_Supine_BP_Systolic',
#        'Supine_BP_Diastolic', 'Supine_BP_Systolic', 'Standing_BP_Diastolic',
#        'Standing_BP_Systolic', 'Onset_Delta'],
#       dtype='object')

# %%
vital['days_since_onset'] = np.abs(vital['Onset_Delta']) + vital['Vital_Signs_Delta']

# %%
print(vital.shape)
vital.head()
# Out:
# (72653, 38)
#    subject_id  Blood_Pressure_Diastolic Blood_Pressure_Diastolic_Units  \
# 0         329                       NaN                            NaN
# 1         329                       NaN                            NaN
# 2         329                       NaN                            NaN
# 3         329                       NaN                            NaN
# 4         329                       NaN                            NaN
#
#    Blood_Pressure_Systolic Blood_Pressure_Systolic_Units  Height Height_Units  \
# 0                      NaN                           NaN   157.5          NaN
# 1                      NaN                           NaN     NaN          NaN
# 2                      NaN                           NaN     NaN          NaN
# 3                      NaN                           NaN     NaN          NaN
# 4                      NaN                           NaN     NaN          NaN
#
#    Pulse Pulse_Units  Respiratory_Rate  ... Endpoint_Standing_BP_Diastolic  \
# 0    NaN         NaN               NaN  ...                            NaN
# 1    NaN         NaN              32.0  ...                            NaN
# 2    NaN         NaN              29.0  ...                            NaN
# 3    NaN         NaN              26.0  ...                            NaN
# 4    NaN         NaN              26.0  ...                            NaN
#
#    Endpoint_Standing_BP_Systolic Endpoint_Supine_BP_Diastolic  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#    Endpoint_Supine_BP_Systolic Supine_BP_Diastolic  Supine_BP_Systolic  \
# 0                          NaN                 NaN                 NaN
# 1                          NaN                70.0               110.0
# 2                          NaN                65.0               107.0
# 3                          NaN                60.0               104.0
# 4                          NaN                70.0               120.0
#
#    Standing_BP_Diastolic  Standing_BP_Systolic  Onset_Delta  days_since_onset
# 0                    NaN                   NaN      -1706.0               NaN
# 1                   60.0                 106.0      -1706.0            1706.0
# 2                   65.0                 107.0      -1706.0            1714.0
# 3                   70.0                 108.0      -1706.0            1722.0
# 4                   64.0                 112.0      -1706.0            1748.0
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Weight

# %%
# weight units
vital['Weight_Units'].value_counts()
# Out:
# Kilograms    35709
# Pounds         286
# Name: Weight_Units, dtype: int64

# %%
# convert pounds to kilograms
vital.loc[ vital['Weight_Units']=="Pounds", 'Weight'] = vital['Weight'] * 0.453592
vital['Weight_Units'].replace('Pounds', 'Kilograms', inplace=True)
vital['Weight_Units'].value_counts()

# %%
# get weights for each subject for use in models.
weight=vital[['subject_id', 'days_since_onset', 'Weight']].copy()
weight.dropna(inplace=True)
weight.reset_index(drop=True, inplace=True)
weight['weight']=weight['Weight']
weight.drop('Weight', axis=1, inplace=True)
print(weight.shape)
weight.head()
# Out:
# (49242, 3)
#    subject_id  days_since_onset  weight
# 0         329            1706.0    52.2
# 1         329            1714.0    52.1
# 2         329            1722.0    52.0
# 3         329            1748.0    49.8
# 4         329            1778.0    45.8

# %%
# how much does weight change for each subject over time?
gr_weight_mean = weight.groupby('subject_id').agg({'weight':['mean', 'std']})
gr_weight_mean.head()
# Out:
#                 weight
#                   mean       std
# subject_id
# 329          45.400000  4.766932
# 348         119.712500  1.790002
# 533          49.833333  2.015564
# 586          61.800000       NaN
# 649          68.050000  7.763258

# %%
# the average standard deviation for each subject is # 2.887 kg
# ok to proceed using first value for weight.
gr_weight_mean['weight']['std'].mean()
# Out:
# 2.823979374570086

# %%
# index of min day
gr_weight = weight.groupby('subject_id')['days_since_onset'].idxmin()
gr_weight.head()
# Out:
# subject_id
# 329     0
# 348    12
# 533    20
# 586    29
# 649    30
# Name: days_since_onset, dtype: int64

# %%
# for each subject, each question's response at max assessment study day 
min_day_weights = weight.iloc[gr_weight]
min_day_weights.head()
# Out:
#     subject_id  days_since_onset  weight
# 0          329            1706.0    52.2
# 12         348             501.0   118.8
# 20         533            1023.0    51.0
# 29         586             715.0    61.8
# 30         649             341.0    73.7

# %%
min_day_weights['days_since_onset'].unique()
# Out:
# array([1706.,  501., 1023., ..., 1589., 1226., 2865.])

# %%
weights = min_day_weights[['subject_id', 'weight']]
weights.reset_index(drop=True, inplace=True)
weights.head()
# Out:
#    subject_id  weight
# 0         329    52.2
# 1         348   118.8
# 2         533    51.0
# 3         586    61.8
# 4         649    73.7

# %%
# weight greater than 115 kg.

# %%
# save scores to file
filename = 'clean_data/weight.csv'
weights.to_csv(filename, index=False)
