# %% [markdown]
# # ALS project
#
# ### EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from pandas_profiling import ProfileReport
import webbrowser, os

# %%
def feature_report(df):
    '''
    print a report of every feature
    '''
    profile = pandas_profiling.ProfileReport(df, bins=30)
    profile.to_file(outputfile="output.html")
    webbrowser.open('file://' + os.path.realpath("output.html"))
    #end function

# %% [markdown]
# ## questionaire

# %%
question = pd.read_csv("data/alsfrs.csv", )

# %%
#feature_report(question)

# %% [markdown]
# see the feature report

# %%
# remove 'Mode_of_Administration' column - empty
question.drop('Mode_of_Administration', axis=1, inplace=True)
# remove 'ALSFRS_Responded_By' column - empty
question.drop('ALSFRS_Responded_By', axis=1, inplace=True)

# %%
# number questionaires per subject
grp_sub_question = question.groupby('subject_id')
n_qs = grp_sub_question['subject_id'].count()
print(n_qs.head())
# Out:
# subject_id
# 329    12
# 348    15
# 533     6
# 586     1
# 649    12
# Name: subject_id, dtype: int64

# %%
question.head()
# Out:
#    subject_id  Q1_Speech  Q2_Salivation  Q3_Swallowing  Q4_Handwriting  \
# 0         329        4.0            3.0            4.0             3.0
# 1         329        4.0            3.0            4.0             3.0
# 2         329        4.0            3.0            4.0             3.0
# 3         329        4.0            3.0            4.0             3.0
# 4         329        4.0            3.0            4.0             3.0
#
#    Q5a_Cutting_without_Gastrostomy  Q5b_Cutting_with_Gastrostomy  \
# 0                              2.0                           NaN
# 1                              1.5                           NaN
# 2                              1.0                           NaN
# 3                              3.0                           NaN
# 4                              2.0                           NaN
#
#    Q6_Dressing_and_Hygiene  Q7_Turning_in_Bed  Q8_Walking  Q9_Climbing_Stairs  \
# 0                      3.0                2.0         2.0                 1.0
# 1                      3.0                2.0         2.0                 1.0
# 2                      3.0                2.0         2.0                 1.0
# 3                      3.0                3.0         2.0                 1.0
# 4                      3.0                4.0         2.0                 2.0
#
#    Q10_Respiratory  ALSFRS_Delta  ALSFRS_Total  ALSFRS_R_Total  R_1_Dyspnea  \
# 0              3.0           0.0          27.0             NaN          NaN
# 1              3.0           8.0          26.5             NaN          NaN
# 2              3.0          16.0          26.0             NaN          NaN
# 3              4.0          42.0          30.0             NaN          NaN
# 4              3.0          72.0          30.0             NaN          NaN
#
#    R_2_Orthopnea  R_3_Respiratory_Insufficiency  ALSFRS_Responded_By
# 0            NaN                            NaN                  NaN
# 1            NaN                            NaN                  NaN
# 2            NaN                            NaN                  NaN
# 3            NaN                            NaN                  NaN
# 4            NaN                            NaN                  NaN

# %% [markdown]
# ## treatment arms

# %%
txt = pd.read_csv("data/Treatment.csv")

# %%
txt.head()
# Out:
#    subject_id Study_Arm  Treatment_Group_Delta
# 0          89    Active                    NaN
# 1         329    Active                    0.0
# 2         348   Placebo                    0.0
# 3         406    Active                    NaN
# 4         411    Active                    NaN

# %%
# look for duplicted subjects in the dataset
print(len(txt))  # 9640
print(len(set(txt['subject_id'])))  #9640 = all unique subjects
# Out:
# 9640
# 9640

# %%
#feature_report(txt)
# placebo = 30.2% of subjects
# active = 69.8% of subjects

# %%
# id's of placebo subjects
placebo = txt.loc[txt['Study_Arm']=='Placebo']
print(len(placebo))
placebo.head()
# Out:
# 2912
#     subject_id Study_Arm  Treatment_Group_Delta
# 2          348   Placebo                    0.0
# 7          902   Placebo                    0.0
# 9         1064   Placebo                    0.0
# 11        1312   Placebo                    0.0
# 16        2132   Placebo                    NaN

# %%
# subjects with at least one questionaire
p = placebo.drop('Treatment_Group_Delta', axis=1)
p_qs = question.merge(p, how='inner', on='subject_id')

# %%
p_qs.head()
# Out:
#    subject_id  Q1_Speech  Q2_Salivation  Q3_Swallowing  Q4_Handwriting  \
# 0         348        4.0            4.0            4.0             3.0
# 1         348        4.0            4.0            4.0             3.0
# 2         348        4.0            4.0            4.0             4.0
# 3         348        4.0            4.0            4.0             4.0
# 4         348        4.0            4.0            4.0             4.0
#
#    Q5a_Cutting_without_Gastrostomy  Q5b_Cutting_with_Gastrostomy  \
# 0                              2.0                           NaN
# 1                              2.0                           NaN
# 2                              2.0                           NaN
# 3                              2.0                           NaN
# 4                              2.0                           NaN
#
#    Q6_Dressing_and_Hygiene  Q7_Turning_in_Bed  Q8_Walking  Q9_Climbing_Stairs  \
# 0                      3.0                4.0         2.0                 1.0
# 1                      2.0                4.0         2.0                 1.0
# 2                      2.0                3.0         2.0                 1.0
# 3                      2.0                3.0         2.0                 1.0
# 4                      2.0                3.0         2.0                 1.0
#
#    Q10_Respiratory  ALSFRS_Delta  ALSFRS_Total  ALSFRS_R_Total  R_1_Dyspnea  \
# 0              NaN           0.0           NaN            39.0          4.0
# 1              NaN           4.0           NaN            38.0          4.0
# 2              NaN          52.0           NaN            38.0          4.0
# 3              NaN          61.0           NaN            38.0          4.0
# 4              NaN          99.0           NaN            38.0          4.0
#
#    R_2_Orthopnea  R_3_Respiratory_Insufficiency  ALSFRS_Responded_By Study_Arm
# 0            4.0                            4.0                  NaN   Placebo
# 1            4.0                            4.0                  NaN   Placebo
# 2            4.0                            4.0                  NaN   Placebo
# 3            4.0                            4.0                  NaN   Placebo
# 4            4.0                            4.0                  NaN   Placebo

# %%
# number questionaires per placebo subject
grp_p_qs = p_qs.groupby('subject_id')
n_p_qs = grp_p_qs['subject_id'].count()
print(n_p_qs.head())
# Out:
# subject_id
# 348     15
# 902      7
# 1064    16
# 1312     1
# 2540     4
# Name: subject_id, dtype: int64
